# %%
#tiffins=["idly","dosa","puri","mysorbajji","chapati","roti","vada","upma","parota","pulka"]
#cust_name=["raju","lakshmi","krishna","ravi","jyothi","umma","pujitha","sruthi","chaitanya","lakshman"]
#previos_rating=[1,5,3,4,5,4,3,2,1,5]
#rating_level_5-10%,4-8%,3-5%,<3-1%

# %%
tiffins=["idly","dosa","puri","mysorbajji","chapati","roti","vada","upma","parota","pulka"]
cust_name=["raju","lakshmi","krishna","ravi","jyothi","umma","pujitha","sruthi","chaitanya","lakshman"]

# %%
def tiffins_delivery(tiffins):
    for tiffin_item in tiffins:
        print("************my_tiffin_items------------>",tiffin_item)
        if tiffin_item=="idly":
            print("------------------------>deliver to raju")
        elif tiffin_item=="dosa": 
            print("------------------------>deliver to lakshmi")
        elif tiffin_item=="puri": 
            print("------------------------>deliver to krishna") 
        elif tiffin_item=="mysorbajji": 
            print("------------------------>deliver to ravi")    
        elif tiffin_item=="chapati": 
            print("------------------------>deliver to jyothi")    
        elif tiffin_item=="roti": 
            print("------------------------>deliver to umma")    
        elif tiffin_item=="vada": 
            print("------------------------>deliver to pujitha")    
        elif tiffin_item=="upma": 
            print("------------------------>deliver to sruthi")    
        elif tiffin_item=="parota": 
            print("------------------------>deliver to chaitanya")    
        elif tiffin_item=="pulka": 
            print("------------------------>deliver to lakshman") 
        else:
            print("------------------------------------------>no delivery")

# %%
tiffins_delivery(tiffins)
# Out:
# ************my_tiffin_items------------> idly
# ------------------------>deliver to raju
# ************my_tiffin_items------------> dosa
# ------------------------>deliver to lakshmi
# ************my_tiffin_items------------> puri
# ------------------------>deliver to krishna
# ************my_tiffin_items------------> mysorbajji
# ------------------------>deliver to ravi
# ************my_tiffin_items------------> chapati
# ------------------------>deliver to jyothi
# ************my_tiffin_items------------> roti
# ------------------------>deliver to umma
# ************my_tiffin_items------------> vada
# ------------------------>deliver to pujitha
# ************my_tiffin_items------------> upma
# ------------------------>deliver to sruthi
# ************my_tiffin_items------------> parota
# ------------------------>deliver to chaitanya
# ************my_tiffin_items------------> pulka
# ------------------------>deliver to lakshman

# %%
tiffins=["idly","dosa","puri","mysorbajji","chapati","roti","vada","upma","parota","pulka"]
cust_name=["raju","lakshmi","krishna","ravi","jyothi","umma","pujitha","sruthi","chaitanya","lakshman"]

# %%
tiffin="idly"
cust_name="raju"
if tiffin=="idly" and cust_name=="raju": 
    print("------------------------>deliver to raju")
elif tiffin=="dosa" and cust_name=="lakshmi": 
    print("----------------------->deliver to lakshmi")
elif tiffin=="puri" and cust_name=="krishna":
    print("------------------------>deliver to krishna")    
elif tiffin=="mysorbajji" and cust_name=="ravi":
    print("-------------------------->deliver to ravi")    
elif tiffin=="chapati" and cust_name=="jyothi":
    print("-------------------------->deliver to jyothi")    
elif tiffin=="roti" and cust_name=="umma":
    print("-------------------------->deliver to umma")    
elif tiffin=="vada" and cust_name=="pujitha":
    print("-------------------------->deliver to pujitha")    
elif tiffin=="upma" and cust_name=="sruthi":
    print("-------------------------->deliver to sruth")    
elif tiffin=="parota" and cust_name=="chaitanya":
    print("------------------------->deliver to chaitanya")    
elif tiffin=="pulka" and cust_name=="lakshman":
    print("-------------------------->deliver to lakshman")    
else:
    print("-------------------->no delivery")
# Out:
# ------------------------>deliver to raju

# %%
tiffin_items=["idly","dosa","puri","mysorbajji","chapati","roti","vada","upma","parota","pulka",]
customer_name=["raju","lakshmi","krishna","ravi","jyothi","umma","pujitha","sruthi","chaitanya","lakshman"]
previos_rating=[1,5,3,4,5,4,3,2,1,5]
overall_amount=[20,40,25,20,30,40,20,25,40,35]

# %%
tiffin_items=["idly","dosa","puri","mysorbajji","chapati","roti","vada","upma","parota","pulka",]
for s in tiffin_items:
    print("******************my tiffin_items----------------->",s)
    for p in customer_name:
        print("****************my customer_name---------------->",p)
        for rating in previos_rating:
            print("*****************my previos_rating------------->",rating)
            if rating==1: 
                discount=overall_amount[0]*0.01
                after_discount=overall_amount[0]-discount
                print("---------------------------->after_discount_______________",after_discount)
            elif rating==5:
                discount=overall_amount[1]*0.10
                after_discount=overall_amount[1]-discount
                print("---------------------------->after_discount_______________",after_discount)
            elif rating==3:
                discount=overall_amount[2]*0.05
                after_discount=overall_amount[2]-discount
                print("---------------------------->after_discount_______________",after_discount)          
            elif rating==4:
                discount=overall_amount[3]*0.08
                after_discount=overall_amount[3]-discount
                print("---------------------------->after_discount_________________",after_discount)       
            elif rating==5:
                discount=overall_amount[4]*0.10
                after_discount=overall_amount[4]-discount
                print("---------------------------->after_discount__________________",after_discount)
            elif rating==4:
                discount=overall_amount[5]*0.08
                after_discount=overall_amount[5]-discount
                print("---------------------------->after_discount__________________",after_discount)    
            elif rating==3:
                discount=overall_amount[6]*0.05
                after_discount=overall_amount[6]-discount
                print("---------------------------->after_discount__________________",after_discount)
            elif rating==2:
                discount=overall_amount[7]*0.01
                after_discount=overall_amount[7]-discount
                print("---------------------------->after_discount__________________",after_discount)
            elif rating==1:
                discount=overall_amount[8]*0.01
                after_discount=overall_amount[8]-discount
                print("---------------------------->after_discount__________________",after_discount)    
            elif rating==5:
                discount=overall_amount[9]*0.10
                after_discount=overall_amount[9]-discount
                print("---------------------------->after_discount__________________",after_discount)    
            else:
                print("***********no rating***********")
# Out:
# ******************my tiffin_items-----------------> idly
# ****************my customer_name----------------> raju
# *****************my previos_rating-------------> 1
# ---------------------------->after_discount_______________ 19.8
# *****************my previos_rating-------------> 5
# ---------------------------->after_discount_______________ 36.0
# *****************my previos_rating-------------> 3
# ---------------------------->after_discount_______________ 23.75
# *****************my previos_rating-------------> 4
# ---------------------------->after_discount_________________ 18.4
# *****************my previos_rating-------------> 5
# ---------------------------->after_discount_______________ 36.0
# *****************my previos_rating-------------> 4
# ---------------------------->after_discount_________________ 18.4
# *****************my previos_rating-------------> 3
# ---------------------------->after_discount_______________ 23.75
# ...
